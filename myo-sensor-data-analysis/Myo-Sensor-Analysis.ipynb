# %% [markdown]
# # Initialise Data

# %% [markdown]
# Import the data, and ensure that no blanks are present (should not be present due to EMG system being automated)

# %%
#Import key modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Show the first 5 rows
df = pd.read_csv('./8-august-at-rest/emg-1533747787.csv')
df.head()
# Out:
#       timestamp  emg1  emg2  emg3  emg4  emg5  emg6  emg7  emg8
# 0  278109348815     0     0     0     0     0     1    -2    -1
# 1  278109348815    -1    -1    -4    -3     0    -1     0     0
# 2  278109357729     0    -1    -2    -2     0     0    -1    -2
# 3  278109357729     0     0     0     1    -1    -1    -1    -1
# 4  278109358383    -3    -1     2    -2    -3    -1    -1    -1

# %%
#Show the main statistics for the data
df.describe()
# Out:
#           timestamp         emg1         emg2         emg3         emg4  \
# count  1.478000e+03  1478.000000  1478.000000  1478.000000  1478.000000
# mean   2.781130e+11    -0.816644    -0.896482    -0.961434    -0.846414
# std    2.139839e+06     0.960038     1.038579     1.041717     1.371964
# min    2.781093e+11    -3.000000    -5.000000    -5.000000    -7.000000
# 25%    2.781112e+11    -1.000000    -2.000000    -2.000000    -2.000000
# 50%    2.781130e+11    -1.000000    -1.000000    -1.000000    -1.000000
# 75%    2.781149e+11     0.000000     0.000000     0.000000     0.000000
# max    2.781167e+11     2.000000     3.000000     3.000000     3.000000
#
#               emg5         emg6         emg7         emg8
# count  1478.000000  1478.000000  1478.000000  1478.000000
# mean     -0.871448    -0.815968    -0.775372    -0.774019
# std       1.214217     1.142502     1.006217     1.008603
# min      -5.000000    -5.000000    -4.000000    -4.000000
# 25%      -2.000000    -2.000000    -1.000000    -1.000000
# 50%      -1.000000    -1.000000    -1.000000    -1.000000
# 75%       0.000000     0.000000     0.000000     0.000000
# max       3.000000     3.000000     3.000000     2.000000

# %%
#Show a basic representation of the EMG1 lead recording
plt.figure(figsize=(14,5))
plt.plot(df.emg1)

# %%
#TO-DO: Normalise the time to a standardised system.
f, axs = plt.subplots(2,4,figsize=(15,15))
plt.subplot(2, 4, 1)
plt.plot(df.timestamp, df.emg1, 'o-')
plt.title('EMG1')
plt.ylabel('Signal')

plt.subplot(2, 4, 2)
plt.plot(df.timestamp, df.emg2, '.-')
plt.title('EMG2')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 3)
plt.plot(df.timestamp, df.emg3, '.-')
plt.title('EMG3')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 4)
plt.plot(df.timestamp, df.emg4, '.-')
plt.title('EMG4')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 5)
plt.plot(df.timestamp, df.emg5, '.-')
plt.title('EMG5')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 6)
plt.plot(df.timestamp, df.emg6, '.-')
plt.title('EMG6')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 7)
plt.plot(df.timestamp, df.emg7, '.-')
plt.title('EMG7')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 8)
plt.plot(df.timestamp, df.emg8, '.-')
plt.title('EMG8')
plt.xlabel('time (s)')
plt.ylabel('Signal intensit')

'''
emg_list = ['df.emg1', 'df.emg2', 'df.emg3', 'df.emg4', 'df.emg5', 'df.emg6', 'df.emg7', 'df.emg8']
for i in range(len(emg_list)):
    plt.subplot(2,4,i)
    plt.plot(df.timestamp, emg_list[i], '.-')
    plt.xlabel('Time(s)')
    plt.ylabel('Signal intensity')
'''
# Out:
# "\nemg_list = ['df.emg1', 'df.emg2', 'df.emg3', 'df.emg4', 'df.emg5', 'df.emg6', 'df.emg7', 'df.emg8']\nfor i in range(len(emg_list)):\n    plt.subplot(2,4,i)\n    plt.plot(df.timestamp, emg_list[i], '.-')\n    plt.xlabel('Time(s)')\n    plt.ylabel('Signal intensity')\n"

# %% [markdown]
# From above, it is evident that EMG leads 3 and 4 gave the best signal (in terms of noise) - considering the positioning of the band on the arm - it could be expected that the movement here was turning the hand to the right, or squeezing the hand.
