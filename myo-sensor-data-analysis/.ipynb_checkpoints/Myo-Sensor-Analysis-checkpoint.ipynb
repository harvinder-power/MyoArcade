# %% [markdown]
# # Initialise Data

# %% [markdown]
# Import the data, and ensure that no blanks are present (should not be present due to EMG system being automated)

# %%
#Import key modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Show the first 5 rows
df = pd.read_csv('./dataset1/emg-1521303702.csv')
df.head()
# Out:
#       timestamp  emg1  emg2  emg3  emg4  emg5  emg6  emg7  emg8
# 0  222716480179     6    -3     0     0    -3     1     0     3
# 1  222716480179   -10     3     0     0     0    -2     1    -1
# 2  222716481663    25     0    -1    -1     1    -2     0     0
# 3  222716481663   -20    -7     0    -2     0     1     3    -7
# 4  222716495030   -34   -12    -3    -1    -1    -1    -2    -4

# %%
#Show the main statistics for the data
df.describe()
# Out:
#           timestamp         emg1         emg2         emg3         emg4  \
# count  1.356000e+03  1356.000000  1356.000000  1356.000000  1356.000000
# mean   2.227199e+11    -0.404130    -1.019174    -0.940265    -0.750737
# std    1.963269e+06    30.332652    33.412103    22.582823    22.096363
# min    2.227165e+11  -128.000000  -128.000000  -119.000000  -116.000000
# 25%    2.227182e+11   -15.000000   -10.000000    -6.000000    -6.000000
# 50%    2.227199e+11     1.000000    -1.000000    -1.000000    -1.000000
# 75%    2.227216e+11    16.000000     8.000000     4.000000     5.000000
# max    2.227233e+11   127.000000   127.000000   127.000000   109.000000
#
#               emg5         emg6         emg7         emg8
# count  1356.000000  1356.000000  1356.000000  1356.000000
# mean     -0.353982    -0.815634     0.056785    -0.091445
# std      30.103022    20.911197    36.327971    36.900611
# min    -126.000000  -117.000000  -128.000000  -128.000000
# 25%      -8.000000    -6.000000   -11.000000   -14.000000
# 50%      -1.000000    -1.000000     0.000000    -1.000000
# 75%       8.000000     5.000000    11.000000    15.000000
# max     124.000000   126.000000   127.000000   127.000000

# %%
#Show a basic representation of the EMG1 lead recording
plt.figure(figsize=(14,5))
plt.plot(df.emg1)

# %%
#TO-DO: Normalise the time to a standardised system.
f, axs = plt.subplots(2,4,figsize=(15,15))
plt.subplot(2, 4, 1)
plt.plot(df.timestamp, df.emg1, 'o-')
plt.title('EMG Subplots')
plt.ylabel('Signal')

plt.subplot(2, 4, 2)
plt.plot(df.timestamp, df.emg2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 3)
plt.plot(df.timestamp, df.emg3, '.-')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 4)
plt.plot(df.timestamp, df.emg4, '.-')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 5)
plt.plot(df.timestamp, df.emg5, '.-')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 6)
plt.plot(df.timestamp, df.emg6, '.-')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 7)
plt.plot(df.timestamp, df.emg7, '.-')
plt.xlabel('time (s)')
plt.ylabel('Signal intensity')

plt.subplot(2, 4, 8)
plt.plot(df.timestamp, df.emg8, '.-')
plt.xlabel('time (s)')
plt.ylabel('Signal intensit')

'''
emg_list = ['df.emg1', 'df.emg2', 'df.emg3', 'df.emg4', 'df.emg5', 'df.emg6', 'df.emg7', 'df.emg8']
for i in range(len(emg_list)):
    plt.subplot(2,4,i)
    plt.plot(df.timestamp, emg_list[i], '.-')
    plt.xlabel('Time(s)')
    plt.ylabel('Signal intensity')
'''
# Out:
# "\nemg_list = ['df.emg1', 'df.emg2', 'df.emg3', 'df.emg4', 'df.emg5', 'df.emg6', 'df.emg7', 'df.emg8']\nfor i in range(len(emg_list)):\n    plt.subplot(2,4,i)\n    plt.plot(df.timestamp, emg_list[i], '.-')\n    plt.xlabel('Time(s)')\n    plt.ylabel('Signal intensity')\n"

# %% [markdown]
# From above, it is evident that EMG leads 3 and 4 gave the best signal - considering the positioning of the band on the arm - it could be expected that the movement here was turning the hand to the right, or squeezing the hand.
